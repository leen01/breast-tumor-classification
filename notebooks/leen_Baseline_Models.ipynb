# %% [markdown]
# # ***Computer Vision Final Project: Breast Cancer Tumor Classification***
# ## Section 1 Spring 2023
# ### Nicholas Lee, Nic Brathwaite, Amir Moayed

# %% [markdown]
# <a href="https://colab.research.google.com/github/NickBrath/Computer-Vision-281-Final-Project/blob/main/Nick_Lee_Baseline_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Possible features of benign tumors to look for in images:
# histologically benign [1]
# 	(adjective) Referring to a lesion that does not meet any criteria of malignancy – e.g., marked cellular atypia, mitosis, disruption of basement membranes, metastasize.

# %% [markdown]
# Consuming TFRecord data
# Refer to the Loading TFRecords tutorial for an end-to-end example.
#
# The tf.data API supports a variety of file formats so that you can process large datasets that do not fit in memory. For example, the TFRecord file format is a simple record-oriented binary format that many TensorFlow applications use for training data. The tf.data.TFRecordDataset class enables you to stream over the contents of one or more TFRecord files as part of an input pipeline.

# %% [markdown]
# look at transfer learning for other similar problems that might help our model https://www.tensorflow.org/guide/keras/transfer_learning

# %% [markdown]
# # Setup

# %%
# Google packages
# from google.colab import drive
# from google.colab import files
# from google.colab.patches import cv2_imshow

# Mount google drive
# drive.mount('/content/drive')

# %%
# base packages
import os
import warnings
import random
from datetime import date
import re
from tqdm.notebook import tqdm  # progress bar library
import glob

# DS packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

# image packages
import PIL
import urllib
import cv2
from skimage.color import rgb2gray
import skimage.io as skio

# ML packages
import scipy as sc
import sklearn as sk
import tensorflow as tf

# %matplotlib inline

# %%
# import tomopy
import mkl
# Intel(R) MKL FFT functions to run sequentially
mkl.domain_set_num_threads(1, domain='fft')
# Out:
# 'success'

# %%
pd.options.display.max_columns = 50
warnings.filterwarnings("ignore")

# %%
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# tf.config.list_physical_devices('GPU')

# %% [markdown]
# ## Functions

# %%
# pickle object for later
import pickle

def pickler(ob, pklFileName):
    """ 
      Create pickle object to load later or in different environments for use later

      ob: object, python object intended to pickle
      pklFileName: string, name of the pickle file e.g. "User/content/drive/209/ThisDataFrame.pkl"
    """

    with open(pklFileName, "wb+") as f:
        pickle.dump(ob, f)


def load_pickles(pklFilePath):
    """
      path: string, path to object
      pklFileName: string, pickle file name with extension .pkl
    """

    return pd.read_pickle(pklFilePath)

# %%
import time

def timeis(func):
    """Decorator that reports the execution time."""

    def wrap(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()

        print(func.__name__, end-start)
        return result
    return wrap

# %% [markdown]
# ## File Paths

# %%
# Paths
main_path = "G:\\My Drive\\"

project_path = "w281_final_project"
project_path = os.path.join(main_path, project_path)

datadir = os.path.join(project_path, "Data")

save_path = "".join([date.today().strftime('%Y%m%d'), "_baseline_models/"])
save_path = "".join([project_path, save_path])

# Sanity Check
print("project path: ", project_path)
print("Data directory", datadir)
print("save path: ", save_path)
# Out:
# project path:  G:\My Drive\w281_final_project
# Data directory G:\My Drive\w281_final_project\Data
# save path:  G:\My Drive\w281_final_project20230409_baseline_models/

# %% [markdown]
# ## Load tensorflow dataset to use in models

# %%
# load metadata information for full paths and annotations
df = load_pickles(os.path.join(datadir, "pickles\metaData.pkl"))

# starting with 40x
df.query('MAGNIFICATION == "40"').reset_index(inplace=True, drop=True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7909 entries, 0 to 7908
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BIOPSY_PROCEDURE  7909 non-null   object
#  1   TUMOR_CLASS       7909 non-null   object
#  2   TUMOR_TYPE        7909 non-null   object
#  3   YEAR              7909 non-null   object
#  4   SLIDE_ID          7909 non-null   object
#  5   MAGNIFICATION     7909 non-null   object
#  6   SEQ               7909 non-null   object
#  7   FULL_PATH         7909 non-null   object
#  8   BASE_NAME         7909 non-null   object
# dtypes: object(9)
# memory usage: 556.2+ KB
#   BIOPSY_PROCEDURE TUMOR_CLASS TUMOR_TYPE YEAR SLIDE_ID MAGNIFICATION  SEQ  \
# 0              SOB           B          A   14  22549AB           100  004
# 1              SOB           B          A   14  22549AB           100  002
# 2              SOB           B          A   14  22549AB           100  003
# 3              SOB           B          A   14  22549AB           100  001
# 4              SOB           B          A   14  22549AB           100  007
#
#                                            FULL_PATH  \
# 0  /content/drive/MyDrive/w281_final_project/Data...
# 1  /content/drive/MyDrive/w281_final_project/Data...
# 2  /content/drive/MyDrive/w281_final_project/Data...
# 3  /content/drive/MyDrive/w281_final_project/Data...
# 4  /content/drive/MyDrive/w281_final_project/Data...
#
#                         BASE_NAME
# 0  SOB_B_A-14-22549AB-100-004.png
# 1  SOB_B_A-14-22549AB-100-002.png
# 2  SOB_B_A-14-22549AB-100-003.png
# 3  SOB_B_A-14-22549AB-100-001.png
# 4  SOB_B_A-14-22549AB-100-007.png

# %%
# swap beginning path from google drive to local computer path
pattern = "/content/drive/MyDrive/"
replacement = "G:/My Drive/"

df['FULL_PATH'] = df['FULL_PATH'].str.replace(pattern, replacement)

# %% [markdown]
# # Quick EDA

# %%
# check distribution of labels
sns.countplot(x=df['TUMOR_TYPE'].values)
# Out:
# <Axes: ylabel='count'>

# %%
df['TUMOR_TYPE'].value_counts(normalize = True)

# %% [markdown]
# DC is by far the most prevelant in the dataset

# %% [markdown]
# ### Examples of images

# %%
# Examples of images
df_temp = df.sample(10).reset_index(drop=True)

nrows = 2
ncols = 5

fig, axs = plt.subplots(nrows, ncols, figsize=(6, 6))

# Flatten axes to make it easier to access
axs = axs.flatten()

for i, file in enumerate(df_temp['FULL_PATH']):
    #read in file
    pic = plt.imread(file)

    # add image to axes
    axs[i].imshow(pic)

    # drop axis labels
    axs[i].axis('off')
    # add axes title
    axs[i].set(title=df_temp.loc[i, 'TUMOR_TYPE'])

fig.suptitle("Sample of images in dataset", fontsize=16)
# Out:
# Text(0.5, 0.98, 'Sample of images in dataset')

# %% [markdown]
# Typically a trained histologist would evalulate the staining of each slide and rank them from 1-5 based on their own criteria. This provides issues when compariing tissues sections from different patients and labs. Processing the tissues and staining with hematoxylin and eosin can cause different artifcats to be present in the slides. Additional variations can come from image capture procedures. Luckily in this dataset the data curators used the same equipment and settings (*fact check please*). Regardless, it may be beneficial to normalize for brightness or intensity of colors. Initially our approach will be to use only grey scale images.

# %% [markdown]
# There are also gaps in some of the tissue that cause the area size to vary between slides.
# Orientation could also be a challenge. The tissue is not always oriented the same way to the view of the tissue can change depending on how the parafin was sectioned and laid on a slide.

# %% [markdown]
# There are substructures within the images that histologist normally use to annotate these images. These features are important because the types of tissues that the cancer is affecting will change the appearance of the slide and staining profile. Understanding the effected cellular structures also helps to lead to diagnosises in the clinic. It would be interesting in future work to use this set to see what structures are effected by different types of cancer.

# %% [markdown]
# # Creating dataset

# %% [markdown]
# More about [batched datasets](https://www.tensorflow.org/guide/data#batching_dataset_elements) can be found there.

# %%
def create_tf_ds(file_paths, labels):
    """ Create tensorflow dataset from file paths and labels """
    # create dataset
    ds = tf.data.Dataset.from_tensor_slices(
        (file_paths, labels))  # mapping like a zip in python

    return ds


def read_image(image_file_path, label):
    """Function to read in images to create tf dataset"""
    
    image = tf.io.read_file(image_file_path)  # read in image
    
    # preserving RGB colors with channels = 3. Reads array
    image = tf.image.decode_image(image, channels=3, dtype=tf.float32)

    return image, label

# %% [markdown]
# ## Label Encoding and Decoding

# %%
# convert labels to numeric representation
from sklearn.preprocessing import LabelEncoder

# create encoder
labelencoder = LabelEncoder()

# %%
file_paths = df['FULL_PATH'].values
# using subtype of tumor labels as labels to get 8 different labels. Could use 'TUMOR_CLASS' if you want binary classification problem.

labels = df['TUMOR_TYPE'].values

## One-hot encoding for labels
# number of categories
depth = len(set(labels))

# apply encoder to change string labels to integer
labels_encoded = labelencoder.fit_transform(labels)

# One-hot encodning to feed into model(s)
labels = tf.one_hot(labels_encoded, depth=depth)

# create dataset (ds)
ds = create_tf_ds(file_paths, labels)
ds
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(8,), dtype=tf.float32, name=None))>

# %% [markdown]
# ### Decode Labels

# %% [markdown]
# *work in progress*

# %%
def decode_labels(labels_encoded): 
    # get labels back out
    return labelencoder.inverse_transform(labels_encoded)

## Example
# get numpy array of values and decode
# tf_labels_encoded = tf.argmax(labels, axis=1).numpy()
# decode_labels(tf_labels_encoded)

# %%
def one_hot_argmax(label): 
    """ Getting the max value will help to decode since we have a 1 x 8 array size"""
    return tf.argmax(label, axis=0).numpy()

# test_label = one_hot_argmax(test_label)
# test_label = np.array(test_label)

# %% [markdown]
# ## Image Augmentation

# %% [markdown]
# - [] Image Sharpening
# - [] Contrast
# - [] GrayScale
# - [] HOG
# - [] Edge Detection
# - [] Feature Tracking
#
# tf functions for images: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image

# %% [markdown]
# https://www.tensorflow.org/api_docs/python/tf/image/extract_patches

# %%
# needs work
# https://www.tensorflow.org/api_docs/python/tf/image/crop_and_resize

def augment_resize(image, label, size = 120): 
    # normalize image size to a square and get smaller subsection
    offsetwidth = offsetheight = size
    image = tf.image.crop_to_bounding_box(image, 0, 0, offsetwidth, offsetheight)
    
    return image, label

# %%
def augment_centralcrop(image, label): 
    """take image and return fraction of the image cropped centered"""
    # needs work
    image = tf.image.central_crop(image, 0.5)
    
    return image, label

# %% [markdown]
# #### Random sample 32, 32, 3 like they do in the paper

# %%
def augment_patches(image, label): 
    """ Get patches of image like a convolution"""
    
    image = tf.image.extract_patches(
        images=image,
        sizes=[1, 10, 10, 1],
        strides=[1, 5, 5, 1],
        rates=[1, 1, 1, 1],
        padding='VALID'
        )
    
    return image, label

# %%
def augment_grayscale(image, label):
    # turn image from RGB to grayscale
    if tf.random.uniform((), minval=0, maxval=1) < 0.1:
        image = tf.tile(tf.image(tf.image.rgb_to_grayscale(image), [1, 1, 3]))
    
    return image, label

# %%
def augment_sharpen(image, label): 
    
    # image sharpening
    
    return image, label

# %%
# image sharpening
def augment_contrast(image, label): 
    """ Adjust contrast of image """
    
    image = tf.image.random_contrast(image, lower=0.1, upper=0.5)
    
    return image, label

# %%
def augment_normalize(image, label):
    """ Normalize images for pixel intensity variations to gaussian distribution"""
    
    return tf.cast(image, tf.float32) / 255.0, label

# %%
def augment_brightness(image, label): 
    """ Change image brightness on pixels a random amount """
    image = tf.image.random_brightness(image, max_delta=0.1)
    
    return image, label

# %%
def augment_flip(image,label):
    """ horizontal and vertically flip images"""
    image = tf.image.random_flip_left_right(image)  # 50%
    image = tf.image.random_flip_up_down(image)
    
    return image, label

# %%
def augment_rotation(image, label): 
    """ """
    
    image = tf.keras.preprocessing.image.random_rotation(image)
    
    return image, label

# %%
def augment(image, label):
    # data augmentation here
    # is done while the model is training
    # did it this way to change which augmentations are applied. Thought it would be easier to break down functions into parts. 

    # image, label = augment_normalize(image,label)
    
    image, label = augment_resize(image,label)
    
    image, label = augment_grayscale(image,label)
    
    image, label = augment_sharpen(image,label)
    
    image, label = augment_brightness(image,label)
    
    image, label = augment_contrast(image,label)
    
    image, label = augment_flip(image,label)
   
    return image, label

# %% [markdown]
# ## Testing Different Augmentations

# %% [markdown]
# ### Functions for viewing images

# %%
def plot_images(images, nrows, ncols = 1): 
    """ List of image dictionaries with label: value, im: array"""

    fig, axs = plt.subplots(nrows, ncols, figsize=(10, 10))

    # Flatten axes to make it easier to access
    axs = axs.flatten()

    for i, im in enumerate(images):
        #read in file
        # pic = plt.imread(file)
        label = str(im['label'])
        
        im = im['im']

        # add image to axes
        axs[i].imshow(im)
        # drop axis labels
        axs[i].axis('off')
        # add axes title
        axs[i].set(title=label)
        
    fig.suptitle("Sample of images in dataset", fontsize=16)

    plt.show()

# %%
def plot_images_with_histogram(images, nrows): 
    """ List of image dictionaries with label: value, im: array"""

    fig, axs = plt.subplots(nrows, ncols = 2, figsize=(10, 10))

    # Flatten axes to make it easier to access
    # axs = axs.flatten()

    for i, im in enumerate(images):
        #read in file
        # pic = plt.imread(file)
        label = str(im['label'])
        
        im = im['im']
        # add image to axes
        axs[i, 0].imshow(im)
        # drop axis labels
        axs[i, 0].axis('off')
        # add axes title
        axs[i, 0].set(title=label)
        
        # add histogram 
        axs[i, 1].hist((im*255).ravel(), bins = 100, fc='k', ec='k')
        
    fig.suptitle("Sample of images in dataset", fontsize=16)

    plt.show()

# %%
def create_image_set(ds, num_images = 5): 
    # create preview of images with labels
    images = []
    for i, t in enumerate(ds.take(num_images)): 
        images.append(
            {'label': tf.argmax(t[1].numpy()).numpy(), 
            'im' : t[0].numpy()}
        )

    return images

# %% [markdown]
# ### Testing augmentations
# Map different augment functions to the dataset as below

# %% [markdown]
# #### Base images unaltered

# %%
ds
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(8,), dtype=tf.float32, name=None))>

# %%
ds_temp = ds.map(read_image)
images_base = create_image_set(ds_temp, 5)

# %% [markdown]
# #### Resizing

# %%
ds_temp = ds.map(read_image).map(augment_resize)
image_resize = create_image_set(ds_temp, 5)

plot_images(image_resize, 5)

# %% [markdown]
# #### Contrast

# %%
plot_images_with_histogram(images_base, nrows = len(images_base))

# %%
# Contrast
ds_temp = ds.map(read_image).map(augment_contrast)
images_contrast = create_image_set(ds_temp, 5)

## create general view of images
# plot_images(images_contrast, nrows = len(images_contrast))
plot_images_with_histogram(images_contrast, nrows = len(images_contrast))

# %% [markdown]
# We can have an unequal distribution of pixels due to the sectioning of the tissue

# %% [markdown]
# Can we normalize the contrast and pixel intensities found in the images?

# %% [markdown]
# ### Edges Investigation

# %%
# grad_components = tf.image.sobel_edges(img)

# %% [markdown]
# # Model Creation

# %%
from tensorflow import keras

# %%
def plot_hist(hist): 
    """ View into model history. 
    hist = model.fit() results"""
    hist_dict = hist.history
    hist_df = pd.DataFrame.from_dict(hist_dict)

    # Use index to get Epochs
    hist_df.reset_index(inplace = True)
    hist_df.rename({'index': 'Epoch'}, axis = 1, inplace = True)
    # hist_df = pd.melt(hist_df, id_vars = 'index')

    # Create Subsets
    accuracy = hist_df.loc[:, ['Epoch','accuracy', 'val_accuracy']]
    loss = hist_df.loc[:, ['Epoch', 'loss', 'val_loss']]

    # Flatten dfs
    accuracy = pd.melt(accuracy, id_vars = 'Epoch')
    loss = pd.melt(loss, id_vars = 'Epoch')

    # flatten df to plot
    # hist_melt = pd.melt(hist_df, id_vars = 'index').rename({'index': 'Epoch'}, axis = 1)

    # call regplot on each axes
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False)

    sns.lineplot(data = accuracy, ax = ax1, x = 'Epoch', y = 'value', hue = 'variable').set_title('Accuracy')
    sns.lineplot(data = loss, ax = ax2, x = 'Epoch', y = 'value', hue = 'variable').set_title('Loss')

# %% [markdown]
# ## Train, test split

# %% [markdown]
# More info on splitting data in [tensorflow](https://www.tensorflow.org/datasets/splits)

# %%
def augment_images(image, label):
    # data augmentation here
    # is done while the model is training
    # did it this way to change which augmentations are applied. Thought it would be easier to break down functions into parts. 

    # image, label = augment_normalize(image,label)
    
    image, label = augment_resize(image,label)
    
    # image, label = augment_grayscale(image,label)
    
    # image, label = augment_sharpen(image,label)
    
    # image, label = augment_brightness(image,label)
    
    # image, label = augment_contrast(image,label)
    
    # image, label = augment_flip(image,label)
   
    return image, label

# %%
DATASET_SIZE = ds.cardinality().numpy()

train_size = int(0.7 * DATASET_SIZE)
val_size = int(0.10 * DATASET_SIZE)
test_size = int(0.20 * DATASET_SIZE)

ds = ds.shuffle(buffer_size= DATASET_SIZE)
train_ds = ds.take(train_size)
test_ds = ds.skip(train_size)
val_ds = test_ds.skip(val_size)
test_ds = test_ds.take(test_size)

print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
print(tf.data.experimental.cardinality(test_ds).numpy())
# Out:
# 5536
# 1583
# 1581

# %%
class model_ds: 
    def __init__(self, ds): 
        self.ds = ds
        AUTOTUNE = tf.data.AUTOTUNE
    
    def __str__(self): 
        "Creating dataset for model"
        
    # def configure_for_performance(ds):
    # ds = ds.cache()
    # ds = ds.shuffle(buffer_size=1000)
    # ds = ds.batch(batch_size)
    # ds = ds.prefetch(buffer_size=AUTOTUNE)
    # return ds
    
    def create_set(self): 
        """ Creating the optimized dataset to run on model. Then augment images as necessary"""
        
        self.ds = self.ds.cache().prefetch(buffer_size=AUTOTUNE)
        
        # Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
        self.ds = self.ds.map(read_image, num_parallel_calls=AUTOTUNE).map(augment_images, num_parallel_calls=AUTOTUNE)

# %%
# Trying to create shortcut for apply the same transformations to all datasets
# train_ds = model_ds(train_ds).create_set()
# val_ds = model_ds(val_ds)

# %% [markdown]
# Optimize datasets for training model

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(read_image, num_parallel_calls=AUTOTUNE).map(augment_images, num_parallel_calls=AUTOTUNE)

test_ds = test_ds.map(read_image,  num_parallel_calls=AUTOTUNE).map(augment_images, num_parallel_calls=AUTOTUNE)

val_ds = val_ds.map(read_image,  num_parallel_calls=AUTOTUNE).map(augment_images, num_parallel_calls=AUTOTUNE)

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (120, 120, 3)
# (8,)

# %%
train_sample = create_image_set(train_ds, 5)
plot_images(train_sample, nrows=len(train_sample))

# %% [markdown]
# Configuring for performance
#
# To train a model with this dataset you will want the data:
# - To be well shuffled.
# - To be batched.
# - Batches to be available as soon as possible.
#
# https://www.tensorflow.org/tutorials/load_data/images#standardize_the_data

# %%
batch_size = 32

def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %% [markdown]
# ## Building the base model

# %%
# Create a checkpoint directory to store the checkpoints.
# checkpoint_dir = './training_checkpoints'
# checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

# %%
num_classes = 8

model = tf.keras.Sequential([
  tf.keras.layers.Input((120, 120, 3)),
  tf.keras.layers.Conv2D(16, 3, activation='relu'), # same as kernel size of (3,3)
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 118, 118, 16)      448
#
#  max_pooling2d_12 (MaxPoolin  (None, 59, 59, 16)       0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 55696)             0
#
#  dense_12 (Dense)            (None, 128)               7129216
#
#  dense_13 (Dense)            (None, 8)                 1032
#
# =================================================================
# Total params: 7,130,696
# Trainable params: 7,130,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
  metrics=['accuracy',
    tf.keras.metrics.Precision(), 
    tf.keras.metrics.TruePositives(thresholds=0),
    tf.keras.metrics.TrueNegatives(thresholds=0),
    tf.keras.metrics.FalseNegatives(thresholds=0),
    tf.keras.metrics.FalsePositives(thresholds=0)])

hist = model.fit(
  train_ds,
  verbose = 1,
  validation_data=val_ds,
  epochs=3
)
# Out:
# Epoch 1/3
# 173/173 [==============================] - 11s 61ms/step - loss: 1.9268 - accuracy: 0.4297 - precision_8: 0.4740 - true_positives_8: 2499.0000 - true_negatives_8: 33671.0000 - false_negatives_8: 3037.0000 - false_positives_8: 5081.0000 - val_loss: 1.8777 - val_accuracy: 0.4232 - val_precision_8: 0.4232 - val_true_positives_8: 670.0000 - val_true_negatives_8: 10168.0000 - val_false_negatives_8: 913.0000 - val_false_positives_8: 913.0000
# Epoch 2/3
# 173/173 [==============================] - 11s 65ms/step - loss: 1.8332 - accuracy: 0.4310 - precision_8: 0.4310 - true_positives_8: 2386.0000 - true_negatives_8: 35602.0000 - false_negatives_8: 3150.0000 - false_positives_8: 3150.0000 - val_loss: 1.8186 - val_accuracy: 0.4232 - val_precision_8: 0.4232 - val_true_positives_8: 670.0000 - val_true_negatives_8: 10168.0000 - val_false_negatives_8: 913.0000 - val_false_positives_8: 913.0000
# Epoch 3/3
# 173/173 [==============================] - 11s 63ms/step - loss: 1.7912 - accuracy: 0.4310 - precision_8: 0.4310 - true_positives_8: 2386.0000 - true_negatives_8: 35602.0000 - false_negatives_8: 3150.0000 - false_positives_8: 3150.0000 - val_loss: 1.7965 - val_accuracy: 0.4232 - val_precision_8: 0.4232 - val_true_positives_8: 670.0000 - val_true_negatives_8: 10168.0000 - val_false_negatives_8: 913.0000 - val_false_positives_8: 913.0000

# %% [markdown]
# Plot of training

# %%
plot_hist(hist)

# %%
model.weights[-1].numpy()
# Out:
# array([ 0.06091011,  0.06356955,  0.04054013, -0.11319135, -0.02319272,
#        -0.03613682,  0.01677369, -0.056975  ], dtype=float32)

# %% [markdown]
# Confusion Matrix

# %%
pd.DataFrame(hist.history)
# Out:
#        loss  accuracy  precision_7  true_positives_7  true_negatives_7  \
# 0  1.938563  0.429552     0.406250            2641.0           32269.0
# 1  1.838487  0.430997     0.430997            2386.0           35602.0
# 2  1.792720  0.430997     0.430997            2386.0           35602.0
#
#    false_negatives_7  false_positives_7  val_loss  val_accuracy  \
# 0             2895.0             6483.0  1.883747      0.423247
# 1             3150.0             3150.0  1.821297      0.423247
# 2             3150.0             3150.0  1.796292      0.423247
#
#    val_precision_7  val_true_positives_7  val_true_negatives_7  \
# 0         0.423247                 670.0               10168.0
# 1         0.423247                 670.0               10168.0
# 2         0.423247                 670.0               10168.0
#
#    val_false_negatives_7  val_false_positives_7
# 0                  913.0                  913.0
# 1                  913.0                  913.0
# 2                  913.0                  913.0

# %% [markdown]
# size of cancer cells and progress of patients
# brightness contrast, window detection iding siz of window. same window to different resolution
# - feature tracking with TF
#   - integrating into models, post model or pre-processing
#
# - gray scale
# - UMAP
# - sharpening and contrast

# %%
# Baseline TensorFlow model
def create_baseline_cnn(train_ds,val_ds):
    # max_sequence_length, hidden_layers, filters, kernel_size, learning_rate, embedding_size - other parameters excluding for now
    
    """ 
    Creating baseline CNN for comparison
    """
    
    num_classes = 8

    model = tf.keras.Sequential([
    tf.keras.layers.Input((120, 120, 3)),
    tf.keras.layers.Conv2D(16, 3, activation='relu'), # same as kernel size of (3,3)
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes)
    ])

    model.summary()

    model.compile(
    optimizer='adam',
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy',
        tf.keras.metrics.Precision(), 
        tf.keras.metrics.TruePositives(thresholds=0),
        tf.keras.metrics.TrueNegatives(thresholds=0),
        tf.keras.metrics.FalseNegatives(thresholds=0),
        tf.keras.metrics.FalsePositives(thresholds=0)])

    hist = model.fit(
    train_ds,
    verbose = 1,
    validation_data=val_ds,
    epochs=3
    )
    
    return hist

# %%
baseModel = create_baseline_cnn(train_ds,val_ds)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 118, 118, 16)      448
#
#  max_pooling2d_13 (MaxPoolin  (None, 59, 59, 16)       0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 55696)             0
#
#  dense_14 (Dense)            (None, 128)               7129216
#
#  dense_15 (Dense)            (None, 8)                 1032
#
# =================================================================
# Total params: 7,130,696
# Trainable params: 7,130,696
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 173/173 [==============================] - 10s 55ms/step - loss: 2.1304 - accuracy: 0.4380 - precision_9: 0.4820 - true_positives_9: 2573.0000 - true_negatives_9: 34596.0000 - false_negatives_9: 2963.0000 - false_positives_9: 4156.0000 - val_loss: 1.6718 - val_accuracy: 0.4523 - val_precision_9: 0.6012 - val_true_positives_9: 873.0000 - val_true_negatives_9: 9667.0000 - val_false_negatives_9: 710.0000 - val_false_positives_9: 1414.0000
# Epoch 2/3
# 173/173 [==============================] - 9s 52ms/step - loss: 1.5187 - accuracy: 0.4921 - precision_9: 0.5051 - true_positives_9: 3315.0000 - true_negatives_9: 32829.0000 - false_negatives_9: 2221.0000 - false_positives_9: 5923.0000 - val_loss: 1.5516 - val_accuracy: 0.4649 - val_precision_9: 0.4185 - val_true_positives_9: 1032.0000 - val_true_negatives_9: 8452.0000 - val_false_negatives_9: 551.0000 - val_false_positives_9: 2629.0000
# Epoch 3/3
# 173/173 [==============================] - 9s 53ms/step - loss: 1.4517 - accuracy: 0.5042 - precision_9: 0.4670 - true_positives_9: 3745.0000 - true_negatives_9: 31210.0000 - false_negatives_9: 1791.0000 - false_positives_9: 7542.0000 - val_loss: 1.4437 - val_accuracy: 0.5104 - val_precision_9: 0.4819 - val_true_positives_9: 1113.0000 - val_true_negatives_9: 8902.0000 - val_false_negatives_9: 470.0000 - val_false_positives_9: 2179.0000

# %% [markdown]
# # Paper Model:
# Input Layer:
# - some transformations such as mean-subtraction and feature scaling
# - parameters are (32 x 32 or 64 x 64) and 3 channels for RGB
#
# Convolution Layers:
# - (kernels) are of size 5 × 5, the zero-padding is set to 2 and the stride is set to 1.
# - first two convolutional layers learn 32 filters, initialized from Gaussian Distribution with SD of 0.0001 and 0.01 respectively
# - last layer learns 64 filters and intialized from Gaussian distribution with SD of 0.0001
#
# Pooling Layers:
# - responsible for down sampling spatial dimension of input
# - one after each convolution layer
# - 3 x 3 receptive field with stride of 2
# - first uses max operation over receptive field and other two are average pooling
#
# ReLU Layers:
# - Treating as a layer
# - Given an input value x, the ReLU layer computes the neuron’s output f(x) as x if x > 0 and (α × x) if x <= 0. The parameter α specifies whether to leak the negative part by multiplying it with the slope value (0.01 or so) rather than setting it to 0.
# - default α is 0. When not set, $f(x) = max(0,x)$ aka activation threshold at zero
#
# Inner-product layers (fully connected layers):
# - input treated as vector and produce output in form of single vector
# - two inner-product layers
# - the last is a fully-connected output layer with softmax activation and depends on number of classes for classification problem 2 for binary classification

# %%
num_classes = 8

model = tf.keras.Sequential([
    tf.keras.layers.Input((120, 120, 3)),
    tf.keras.layers.Conv2D(filters=32, kernel_size=(5,5), strides = (1,1), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(units=num_classes, activation='softmax')
])

model.summary()

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy',
        tf.keras.metrics.Precision(), 
        tf.keras.metrics.TruePositives(thresholds=0),
        tf.keras.metrics.TrueNegatives(thresholds=0),
        tf.keras.metrics.FalseNegatives(thresholds=0),
        tf.keras.metrics.FalsePositives(thresholds=0)]
)

hist = model.fit(
    train_ds,
    verbose = 0,
    validation_data=val_ds,
    epochs=3
)

plot_hist(hist)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 116, 116, 32)      2432
#
#  max_pooling2d_17 (MaxPoolin  (None, 58, 58, 32)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 64)        18496
#
#  max_pooling2d_18 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 50176)             0
#
#  dense_20 (Dense)            (None, 128)               6422656
#
#  dense_21 (Dense)            (None, 8)                 1032
#
# =================================================================
# Total params: 6,444,616
# Trainable params: 6,444,616
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The main idea is to extract from the high resolution
# images patches with sizes that are close to those of the CIFAR
# dataset. Since we are dealing with textures, the main premise is
# that these patches can contain enough information for training
# a model, provided an appropriate set of patches is extracted
# from each image.
#
# Two Strategies:
# 1. 32 x 32 window with 50% overlap
# 2. 64 x 64 window with no overlap and random sampling on image

# %%
learningRate = 1E-6

# %%
momentumTerm = 0.9

# %%
weightDecay = 4e-5

# %%
iterations = 8e5

# %% [markdown]
# # Creating Model

# %%
def model_checkpoint_constructor(checkpoint_name): 
    # Define the callback to save the model weights
    checkpoint_path = os.path.join(r"..\models\checkpoints", checkpoint_name)
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_path,
        save_weights_only=True,
        monitor="accuracy",
        save_best_only=True,
        verbose=1
    )
    
    return checkpoint_callback

# %%
checkpoint_callback = model_checkpoint_constructor("model_checkpoint.h5")

# %%
# Define the callback to save the model weights
# checkpoint_path = r"..\models\checkpoints\model_checkpoint.h5"
# checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_path,
#     save_weights_only=True,
#     monitor="accuracy",
#     save_best_only=True,
#     verbose=1
# )

# Train the model with the callback
hist = model.fit(
    train_ds,
    epochs=10,
    batch_size=32,
    validation_data=val_ds,
    callbacks=[checkpoint_callback]
)

plot_hist(hist)
# Out:
# Epoch 1/10
# 173/173 [==============================] - ETA: 0s - loss: 0.7547 - accuracy: 0.7303 - precision_12: 0.8422 - true_positives_12: 5536.0000 - true_negatives_12: 0.0000e+00 - false_negatives_12: 0.0000e+00 - false_positives_12: 38752.0000
# Epoch 1: accuracy improved from -inf to 0.73031, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 19s 112ms/step - loss: 0.7547 - accuracy: 0.7303 - precision_12: 0.8422 - true_positives_12: 5536.0000 - true_negatives_12: 0.0000e+00 - false_negatives_12: 0.0000e+00 - false_positives_12: 38752.0000 - val_loss: 1.1126 - val_accuracy: 0.6570 - val_precision_12: 0.7444 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 0.0000e+00 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11081.0000
# Epoch 2/10
# 173/173 [==============================] - ETA: 0s - loss: 0.6161 - accuracy: 0.7854 - precision_12: 0.8751 - true_positives_12: 5536.0000 - true_negatives_12: 0.0000e+00 - false_negatives_12: 0.0000e+00 - false_positives_12: 38752.0000
# Epoch 2: accuracy improved from 0.73031 to 0.78540, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 21s 119ms/step - loss: 0.6161 - accuracy: 0.7854 - precision_12: 0.8751 - true_positives_12: 5536.0000 - true_negatives_12: 0.0000e+00 - false_negatives_12: 0.0000e+00 - false_positives_12: 38752.0000 - val_loss: 1.0575 - val_accuracy: 0.6980 - val_precision_12: 0.7886 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 0.0000e+00 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11081.0000
# Epoch 3/10
# 173/173 [==============================] - ETA: 0s - loss: 0.5352 - accuracy: 0.8107 - precision_12: 0.8860 - true_positives_12: 5536.0000 - true_negatives_12: 4.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38748.0000
# Epoch 3: accuracy improved from 0.78540 to 0.81069, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 20s 116ms/step - loss: 0.5352 - accuracy: 0.8107 - precision_12: 0.8860 - true_positives_12: 5536.0000 - true_negatives_12: 4.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38748.0000 - val_loss: 1.0774 - val_accuracy: 0.7176 - val_precision_12: 0.7920 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 0.0000e+00 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11081.0000
# Epoch 4/10
# 173/173 [==============================] - ETA: 0s - loss: 0.4201 - accuracy: 0.8522 - precision_12: 0.9120 - true_positives_12: 5536.0000 - true_negatives_12: 15.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38737.0000
# Epoch 4: accuracy improved from 0.81069 to 0.85224, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 20s 116ms/step - loss: 0.4201 - accuracy: 0.8522 - precision_12: 0.9120 - true_positives_12: 5536.0000 - true_negatives_12: 15.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38737.0000 - val_loss: 1.1413 - val_accuracy: 0.7126 - val_precision_12: 0.7857 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 0.0000e+00 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11081.0000
# Epoch 5/10
# 173/173 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.8884 - precision_12: 0.9293 - true_positives_12: 5536.0000 - true_negatives_12: 16.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38736.0000
# Epoch 5: accuracy improved from 0.85224 to 0.88837, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 20s 118ms/step - loss: 0.3348 - accuracy: 0.8884 - precision_12: 0.9293 - true_positives_12: 5536.0000 - true_negatives_12: 16.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38736.0000 - val_loss: 1.1877 - val_accuracy: 0.7663 - val_precision_12: 0.8000 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 0.0000e+00 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11081.0000
# Epoch 6/10
# 173/173 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.9106 - precision_12: 0.9410 - true_positives_12: 5536.0000 - true_negatives_12: 26.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38726.0000
# Epoch 6: accuracy improved from 0.88837 to 0.91059, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 21s 120ms/step - loss: 0.2711 - accuracy: 0.9106 - precision_12: 0.9410 - true_positives_12: 5536.0000 - true_negatives_12: 26.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38726.0000 - val_loss: 1.2149 - val_accuracy: 0.7751 - val_precision_12: 0.7944 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 0.0000e+00 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11081.0000
# Epoch 7/10
# 173/173 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9149 - precision_12: 0.9461 - true_positives_12: 5536.0000 - true_negatives_12: 48.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38704.0000
# Epoch 7: accuracy improved from 0.91059 to 0.91492, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 21s 121ms/step - loss: 0.2466 - accuracy: 0.9149 - precision_12: 0.9461 - true_positives_12: 5536.0000 - true_negatives_12: 48.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38704.0000 - val_loss: 1.3627 - val_accuracy: 0.7783 - val_precision_12: 0.8081 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 1.0000 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11080.0000
# Epoch 8/10
# 173/173 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9449 - precision_12: 0.9636 - true_positives_12: 5536.0000 - true_negatives_12: 70.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38682.0000
# Epoch 8: accuracy improved from 0.91492 to 0.94491, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 20s 117ms/step - loss: 0.1724 - accuracy: 0.9449 - precision_12: 0.9636 - true_positives_12: 5536.0000 - true_negatives_12: 70.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38682.0000 - val_loss: 1.3982 - val_accuracy: 0.7903 - val_precision_12: 0.8000 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 9.0000 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11072.0000
# Epoch 9/10
# 173/173 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9505 - precision_12: 0.9648 - true_positives_12: 5536.0000 - true_negatives_12: 79.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38673.0000
# Epoch 9: accuracy improved from 0.94491 to 0.95051, saving model to ..\models\checkpoints\model_checkpoint.h5
# 173/173 [==============================] - 21s 119ms/step - loss: 0.1602 - accuracy: 0.9505 - precision_12: 0.9648 - true_positives_12: 5536.0000 - true_negatives_12: 79.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38673.0000 - val_loss: 1.4393 - val_accuracy: 0.7808 - val_precision_12: 0.7985 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 15.0000 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11066.0000
# Epoch 10/10
# 173/173 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.9424 - precision_12: 0.9589 - true_positives_12: 5536.0000 - true_negatives_12: 100.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38652.0000
# Epoch 10: accuracy did not improve from 0.95051
# 173/173 [==============================] - 20s 115ms/step - loss: 0.1793 - accuracy: 0.9424 - precision_12: 0.9589 - true_positives_12: 5536.0000 - true_negatives_12: 100.0000 - false_negatives_12: 0.0000e+00 - false_positives_12: 38652.0000 - val_loss: 1.3415 - val_accuracy: 0.7757 - val_precision_12: 0.8042 - val_true_positives_12: 1583.0000 - val_true_negatives_12: 23.0000 - val_false_negatives_12: 0.0000e+00 - val_false_positives_12: 11058.0000

# %%
plot_hist(history)

# %% [markdown]
# ### Evaluate Model

# %%
model.predict(test_ds)

# %% [markdown]
# ### Load Model

# %%
# Load the best model weights from the checkpoint
# model.load_weights(checkpoint_path)

# %% [markdown]
# # Model Performance
#
#
# $\text{Patient Score} = \frac{N_{rec}}{N_p}$
#
# ## Global Patient Recognition Rate
# $\text{Patient Recognition Rate} = \frac{\Sigma Patient Score}{Total Number of Patients}$
#
# $\text{Image Recognition Rate} = \frac{N_{rec}}{N_{all}}$

# %% [markdown]
# # Export Model

# %%
# from datetime import datetime
# t = datetime.now().strftime("%Y%m%d_%H%M%S")
# export_path = "./models/soft-f1_{}".format(t)
# tf.keras.experimental.export_saved_model(model, export_path)
# print("Model with macro soft-f1 was exported in this path: '{}'".format(export_path))

# %%
# reloaded = tf.keras.experimental.load_from_saved_model(export_path,
#                                                        custom_objects={'KerasLayer':hub.KerasLayer})
