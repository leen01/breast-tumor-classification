# %% [markdown]
# A single notebook didn't have enough processing power for all the images and models to run at once

# %%
from google.colab import drive
from google.colab import files
from google.colab.patches import cv2_imshow

import os
import warnings
import random
from datetime import date
import re
import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

import PIL
import urllib
import cv2
from skimage.color import rgb2gray
import skimage.io as skio
from skimage.feature import hog

import scipy as sc
import sklearn as sk
import tensorflow as tf
# import tensorflow_addons as tfa

# %matplotlib inline

# %%
# Mount google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Paths
main_path = "/content/drive/MyDrive/"

project_path = "w281_final_project/"
data_path_benign = "Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/"
data_path_malignant = "Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/malignant/"
save_path = "".join([date.today().strftime('%Y%m%d'), "_baseline_models/"])

project_path = "".join([main_path, project_path])
data_path_benign = "".join([project_path, data_path_benign])
data_path_malignant = "".join([project_path, data_path_malignant])
save_path = "".join([project_path, save_path])

# Sanity Check
print("project path: ", project_path)
print("data path benign: ", data_path_benign)
print("data path malignant: ", data_path_malignant)
print("save path: ", save_path)
# Out:
# project path:  /content/drive/MyDrive/w281_final_project/
# data path benign:  /content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/
# data path malignant:  /content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/malignant/
# save path:  /content/drive/MyDrive/w281_final_project/20230424_baseline_models/

# %%
# Benign and Malignant Directories
benign_directory = "".join([data_path_benign, "SOB/"])
malignant_directory = "".join([data_path_malignant, "SOB/"])

print("SOB benign", benign_directory)
print("SOB malignant", malignant_directory)
# Out:
# SOB benign /content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/
# SOB malignant /content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/malignant/SOB/

# %%
# Folders & Resolution
forty = "40X"
one_hundred = "100X"
two_hundred = "200X"
four_hundred = "400X"

# %%
# pickle object for later
import pickle

def pickler(ob, pklFileName):
    """ 
      Create pickle object to load later or in different environments for use later

      ob: object, python object intended to pickle
      pklFileName: string, name of the pickle file e.g. "User/content/drive/209/ThisDataFrame.pkl"
    """

    with open(pklFileName, "wb+") as f:
        pickle.dump(ob, f)


def load_pickles(pklFilePath):
    """
      path: string, path to object
      pklFileName: string, pickle file name with extension .pkl
    """

    return pd.read_pickle(pklFilePath)

# %%
class fileMetaData: 
  def __init__(fileName): 
    self.fileName = fileName

# %%
labels = {
    "BIOPSY_PROCEDURE": "", 
    "TUMOR_CLASS": "", 
    "TUMOR_TYPE":"", 
    "YEAR": "",
    "SLIDE_ID": "", 
    "MAGNIFICATION": "",
    "SEQ":""
}

# %%
# categories
categories = {'B': 'Benign',
              'M': 'Malignant',
              'A': 'Adenosis',
              'F': 'Fibroadenoma',
              'TA': 'Tubular Adenoma',
              'PT': 'Phyllodes Tumor',
              'DC': 'Ductal Carcinoma',
              'LC': 'Lobular Carcinoma',
              'MC': 'Mucinous Carcinoma (Colloid)',
              'PC': 'Papillary Carcinoma'}

# %%
def metaDataCreator(fileName):
  """
    Separate out the parts of a file name to get the annotations
  """

  metaKeys = ['BIOPSY_PROCEDURE',
            'TUMOR_CLASS',
            'TUMOR_TYPE',
            'YEAR',
            'SLIDE_ID',
            'MAGNIFICATION',
            'SEQ']

  test = str.split(fileName, sep = ".")[0]
  test = str.split(test, sep = "_")
  test2 = str.split(test[-1], sep = "-")
  test = test[:-1]
  metaValues = test + test2
  if len(metaValues) == 7: 
    return {metaKeys[i]:metaValues[i] for i in range(len(metaValues))}
  else: 
    return None

# %%
file = "SOB_B_A-14-22549AB-100-001.png"
metaDataCreator(file)
# Out:
# {'BIOPSY_PROCEDURE': 'SOB',
#  'TUMOR_CLASS': 'B',
#  'TUMOR_TYPE': 'A',
#  'YEAR': '14',
#  'SLIDE_ID': '22549AB',
#  'MAGNIFICATION': '100',
#  'SEQ': '001'}

# %%
Benign_fileList = os.listdir(benign_directory)
Malignant_fileList = os.listdir(malignant_directory)
Malignant_fileList
# Out:
# ['ductal_carcinoma',
#  'lobular_carcinoma',
#  'mucinous_carcinoma',
#  'papillary_carcinoma']

# %%
def fileNameGetter(f):
  return f.split("/")[-1]

# %%
df = load_pickles(os.path.join("/content/drive/MyDrive/w281_final_project/Data/pickles", "metaData.pkl"))

# starting with 40x
df.query('MAGNIFICATION == "40"').reset_index(inplace=True, drop = True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7909 entries, 0 to 7908
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BIOPSY_PROCEDURE  7909 non-null   object
#  1   TUMOR_CLASS       7909 non-null   object
#  2   TUMOR_TYPE        7909 non-null   object
#  3   YEAR              7909 non-null   object
#  4   SLIDE_ID          7909 non-null   object
#  5   MAGNIFICATION     7909 non-null   object
#  6   SEQ               7909 non-null   object
#  7   FULL_PATH         7909 non-null   object
#  8   BASE_NAME         7909 non-null   object
# dtypes: object(9)
# memory usage: 556.2+ KB
#   BIOPSY_PROCEDURE TUMOR_CLASS TUMOR_TYPE YEAR SLIDE_ID MAGNIFICATION  SEQ  \
# 0              SOB           B          A   14  22549AB           100  004
# 1              SOB           B          A   14  22549AB           100  002
# 2              SOB           B          A   14  22549AB           100  003
# 3              SOB           B          A   14  22549AB           100  001
# 4              SOB           B          A   14  22549AB           100  007
#
#                                            FULL_PATH  \
# 0  /content/drive/MyDrive/w281_final_project/Data...
# 1  /content/drive/MyDrive/w281_final_project/Data...
# 2  /content/drive/MyDrive/w281_final_project/Data...
# 3  /content/drive/MyDrive/w281_final_project/Data...
# 4  /content/drive/MyDrive/w281_final_project/Data...
#
#                         BASE_NAME
# 0  SOB_B_A-14-22549AB-100-004.png
# 1  SOB_B_A-14-22549AB-100-002.png
# 2  SOB_B_A-14-22549AB-100-003.png
# 3  SOB_B_A-14-22549AB-100-001.png
# 4  SOB_B_A-14-22549AB-100-007.png

# %%
print("Total entries in the dataset", len(df))
# Out:
# Total entries in the dataset 7909

# %%
### Create a list of fileNames for images in each category of benign or malignant directory
def fileListGenerator(directories, benign = True):
  """
  Input: List of directories within Benign or Malignant folder
  Output: An array of lists for each image
  """
  imageNames = { d: None for d in directories}
  for i in directories:
    if benign:
      directory = "".join([benign_directory, i])
      fileList = glob.glob(directory + "/**/*.png", recursive=True)
      imageNames[i] = fileList
    else:
      directory = "".join([malignant_directory, i])
      fileList = glob.glob(directory + "/**/*.png", recursive=True)
      imageNames[i] = fileList
  return imageNames

# %%
### Store all benign png images into a seperate array with metadata
def separate_tumors(inputLst):
  """
  Input: List of Directories in Benign or Malignant Folder
  Output: List of Dictionaries containing the metadata for each image un sub directories
  """
  tumor_array = []
  for i in inputLst:
    new_directory = "".join([benign_directory, i])
    fileList = glob.glob(new_directory + "/**/*.png", recursive=True)
    files = list(map(fileNameGetter, fileList))
    tumor_array.append({file:metaDataCreator(file) for file in files})
  return tumor_array

# %%
### Create a dictionary containing the directory for each image and the tumor label
benign_files = fileListGenerator(Benign_fileList)
malignant_files = fileListGenerator(Malignant_fileList, benign=False)
benign_files
# Out:
# {'adenosis': ['/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-032.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-031.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/40X/SOB_B_A-14-22549AB-40-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-033.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-036.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-032.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-031.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-035.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-034.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-031.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-033.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-021.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-034.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-035.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-031.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-024.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-032.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-026.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-027.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-029.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-025.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-030.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-022.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-018.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-034.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-028.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-019.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-023.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-020.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-032.png',
# ...
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/400X/SOB_B_TA-14-21978AB-400-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/400X/SOB_B_TA-14-21978AB-400-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/400X/SOB_B_TA-14-21978AB-400-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/400X/SOB_B_TA-14-21978AB-400-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/400X/SOB_B_TA-14-21978AB-400-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/400X/SOB_B_TA-14-21978AB-400-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-21978AB/40X/SOB_B_TA-14-21978AB-40-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/100X/SOB_B_TA-14-3411F-100-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/200X/SOB_B_TA-14-3411F-200-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-017.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-016.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/400X/SOB_B_TA-14-3411F-400-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-001.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-009.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-005.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-008.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-006.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-013.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-011.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-007.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-002.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-003.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-012.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-014.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-015.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-004.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-010.png',
#   '/content/drive/MyDrive/w281_final_project/Data/BreaKHis_v1/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/SOB_B_TA_14-3411F/40X/SOB_B_TA-14-3411F-40-016.png']}

# %% [markdown]
# ### Benign Dataset

# %%
### Intialize the File Path and label into separate datasets to load images
benign_adenosis_dataset = pd.DataFrame(benign_files.get('adenosis'), columns=['full_path']) # Benign Adenosis Tumors
benign_fibroadenoma_dataset = pd.DataFrame(benign_files.get('fibroadenoma'), columns=['full_path']) # Benign Fibroadenoma Tumors
benign_phyllodes_tumor_dataset = pd.DataFrame(benign_files.get('phyllodes_tumor'), columns=['full_path']) # Benign Phyllodes Tumors
benign_tubular_adenoma_dataset = pd.DataFrame(benign_files.get('tubular_adenoma'), columns=['full_path']) # Benign Tubular Adenoma Tumors
print(len(benign_adenosis_dataset['full_path']))
benign_adenosis_dataset['label'] = 'A'
benign_fibroadenoma_dataset['label'] = 'F'
benign_phyllodes_tumor_dataset['label'] = 'PT'
benign_tubular_adenoma_dataset['label'] = 'TA'
benign_adenosis_dataset.head()
# Out:
# 444
#                                            full_path label
# 0  /content/drive/MyDrive/w281_final_project/Data...     A
# 1  /content/drive/MyDrive/w281_final_project/Data...     A
# 2  /content/drive/MyDrive/w281_final_project/Data...     A
# 3  /content/drive/MyDrive/w281_final_project/Data...     A
# 4  /content/drive/MyDrive/w281_final_project/Data...     A

# %%
pandas_frames = [benign_adenosis_dataset, benign_fibroadenoma_dataset, benign_phyllodes_tumor_dataset, benign_tubular_adenoma_dataset]
full_benign_dataset = pd.concat(pandas_frames)
full_benign_dataset["class"] = 1
full_benign_dataset.head()
# Out:
#                                            full_path label  class
# 0  /content/drive/MyDrive/w281_final_project/Data...     A      1
# 1  /content/drive/MyDrive/w281_final_project/Data...     A      1
# 2  /content/drive/MyDrive/w281_final_project/Data...     A      1
# 3  /content/drive/MyDrive/w281_final_project/Data...     A      1
# 4  /content/drive/MyDrive/w281_final_project/Data...     A      1

# %%
def magnification(dataset, filePaths):
  """
  Input:
  dataset - Dataset for which image paths are extracted from 
  filePaths - List of full image paths
  Output: 
  dataset with magnification label
  """
  find = re.compile('([-\w]+\.(?:jpg|gif|png))')
  magnifications = []
  for i in filePaths:
    image_file = re.search(find, i)[0]
    meta_data = metaDataCreator(image_file)
    magnifications.append(int(meta_data.get('MAGNIFICATION')))
  dataset["magnification"] = magnifications

# %%
magnification(full_benign_dataset, full_benign_dataset['full_path'])
full_benign_dataset
# Out:
#                                              full_path label  class  \
# 0    /content/drive/MyDrive/w281_final_project/Data...     A      1
# 1    /content/drive/MyDrive/w281_final_project/Data...     A      1
# 2    /content/drive/MyDrive/w281_final_project/Data...     A      1
# 3    /content/drive/MyDrive/w281_final_project/Data...     A      1
# 4    /content/drive/MyDrive/w281_final_project/Data...     A      1
# ..                                                 ...   ...    ...
# 564  /content/drive/MyDrive/w281_final_project/Data...    TA      1
# 565  /content/drive/MyDrive/w281_final_project/Data...    TA      1
# 566  /content/drive/MyDrive/w281_final_project/Data...    TA      1
# 567  /content/drive/MyDrive/w281_final_project/Data...    TA      1
# 568  /content/drive/MyDrive/w281_final_project/Data...    TA      1
#
#      magnification
# 0              100
# 1              100
# 2              100
# 3              100
# 4              100
# ..             ...
# 564             40
# 565             40
# 566             40
# 567             40
# 568             40
#
# [2480 rows x 4 columns]

# %% [markdown]
# ### Malignant Dataset

# %%
malignant_ductal_carcinoma_dataset = pd.DataFrame(malignant_files.get('ductal_carcinoma'), columns=['full_path']) # Malignant Ductal Carcinoma Tumors
malignant_lobular_carcinoma_dataset = pd.DataFrame(malignant_files.get('lobular_carcinoma'), columns=['full_path']) # Malignant Lobuular Carcinoma Tumors
malignant_mucinous_carcinoma_tumor_dataset = pd.DataFrame(malignant_files.get('mucinous_carcinoma'), columns=['full_path']) # Malignant Mucinous Carcinoma Tumors
malignant_papillary_carcinoma_adenoma_dataset = pd.DataFrame(malignant_files.get('papillary_carcinoma'), columns=['full_path']) # Malignant Papillary Carcinoma Tumors
print(len(malignant_ductal_carcinoma_dataset['full_path']))
malignant_ductal_carcinoma_dataset['label'] = 'DC'
malignant_lobular_carcinoma_dataset['label'] = 'LC'
malignant_mucinous_carcinoma_tumor_dataset['label'] = 'MC'
malignant_papillary_carcinoma_adenoma_dataset['label'] = 'PC'
malignant_ductal_carcinoma_dataset.head()
# Out:
# 3451
#                                            full_path label
# 0  /content/drive/MyDrive/w281_final_project/Data...    DC
# 1  /content/drive/MyDrive/w281_final_project/Data...    DC
# 2  /content/drive/MyDrive/w281_final_project/Data...    DC
# 3  /content/drive/MyDrive/w281_final_project/Data...    DC
# 4  /content/drive/MyDrive/w281_final_project/Data...    DC

# %%
malignant_pandas_frames = [malignant_ductal_carcinoma_dataset, malignant_lobular_carcinoma_dataset, malignant_mucinous_carcinoma_tumor_dataset, malignant_papillary_carcinoma_adenoma_dataset]
full_malignant_dataset = pd.concat(malignant_pandas_frames)
full_malignant_dataset["class"] = 0
magnification(full_malignant_dataset, full_malignant_dataset['full_path'])
full_malignant_dataset.head()
# Out:
#                                            full_path label  class  \
# 0  /content/drive/MyDrive/w281_final_project/Data...    DC      0
# 1  /content/drive/MyDrive/w281_final_project/Data...    DC      0
# 2  /content/drive/MyDrive/w281_final_project/Data...    DC      0
# 3  /content/drive/MyDrive/w281_final_project/Data...    DC      0
# 4  /content/drive/MyDrive/w281_final_project/Data...    DC      0
#
#    magnification
# 0            100
# 1            100
# 2            100
# 3            100
# 4            100

# %%
### Example Image
next_directory = "".join([benign_directory, 'adenosis/SOB_B_A_14-22549AB/100X/SOB_B_A-14-22549AB-100-004.png'])
img1 = plt.imread(next_directory)
# img2 = plt.imread(benign_files[0])
plt.imshow(img1, cmap='gray')

# %% [markdown]
# ### Load & Augment Images

# %%
from sklearn.model_selection import train_test_split
from skimage import exposure, data, img_as_float, img_as_ubyte
from scipy import signal
from scipy.ndimage import convolve, gaussian_filter
from skimage.feature import hog

# %%
full_training_dataset = pd.concat([full_benign_dataset, full_malignant_dataset])
full_training_dataset = full_training_dataset.sample(frac=1).reset_index(drop=True)
full_training_dataset.head()
# Out:
#                                            full_path label  class  \
# 0  /content/drive/MyDrive/w281_final_project/Data...    DC      0
# 1  /content/drive/MyDrive/w281_final_project/Data...    MC      0
# 2  /content/drive/MyDrive/w281_final_project/Data...    PC      0
# 3  /content/drive/MyDrive/w281_final_project/Data...     A      1
# 4  /content/drive/MyDrive/w281_final_project/Data...    LC      0
#
#    magnification
# 0            100
# 1             40
# 2             40
# 3             40
# 4            400

# %%
### Number of individual labels of benign and malignant tumors
num_labels = full_training_dataset['label'].unique()
num_labels
# Out:
# array(['DC', 'MC', 'PC', 'A', 'LC', 'TA', 'F', 'PT'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
encoded_labels = le.fit(num_labels)
list_of_encoded_labels = encoded_labels.transform(full_training_dataset['label'])
decoded_labels = encoded_labels.inverse_transform(list_of_encoded_labels)
print(decoded_labels)
print(list_of_encoded_labels)

full_training_dataset["encoded_labels"] = list_of_encoded_labels
# Out:
# ['DC' 'MC' 'PC' ... 'DC' 'PC' 'F']
# [1 4 5 ... 1 5 2]

# %%
### Split datasets into train and validation sets
def train_test_split_data(dataset, x_column, y_column):
  """
  Inputs:
  Dataset - pandas dataframe with directory paths and labels
  Outputs:
  train_data
  train_labels
  valid_data
  valid_labels
  """
  X = dataset[x_column]
  Y = dataset[y_column]
  train_data, valid_data, train_label, valid_label = train_test_split(X, Y, test_size = 0.25, shuffle=True, random_state=44)
  return train_data, valid_data, train_label, valid_label

# %%
### Histogram Equalization Contrast
def histogram_equalization_grayscale(im):
  # img_cdf, bins = exposure.cumulative_distribution(im, 256)
  # container = np.zeros(256)
  # print(img_cdf)
  # container[:bins] = img_cdf
  # holding_image = np.empty(im.shape)
  # for i in range(im.shape[0]):
  #   for y in range(im.shape[1]):
  #     holding_image[i][y] = container[im[i][y]]
  # equalized_image = holding_image
  # equalized_image = img_as_ubyte(equalized_image)
  im = np.resize(im, (400,640))
  equalized_image = exposure.equalize_hist(im, 256) 
  return equalized_image

# %%
### Image Sharpen Contrast
def sharpen_image(image):
  # Blur filter from previous work
  image = np.resize(image, (400,640,3))
  blurred_image = gaussian_filter(image, 3)
  high_frequency_image = image - blurred_image
  sharpened_image = image + high_frequency_image
  return sharpened_image

# %%
def edge_detection(image):
  # Construct a HOG for each image and edge detection

  filter = np.array([[0, -1, 0], [-1, 4, -1], [0, -1, 0]])
  gradients = sc.ndimage.convolve(image, filter)

  histograms = hog(image, orientations = 8, pixels_per_cell=(16,16))

  return gradients, histograms

# %%
### Create and augment an array of images from a dataset
def load_images(filePaths):
  """
  Inputs:
  filePaths - list of directory paths to images
  Outputs:
  an array of loaded images to be used within the model
  """
  image_container = []
  for i in filePaths:
    im = plt.imread(i)
    im = rgb2gray(im)
    im = img_as_ubyte(im)
    im = histogram_equalization(im)
    image_container.append(im)
  return image_container

# %%
### Create image arrays for inputs into the model using histogram equalization
def read_and_grayscale_images(image_paths, labels):
  img1 = tf.io.read_file(image_paths)
  img1 = tf.image.decode_image(img1, channels=3, dtype=tf.float32)
  img1 = tf.image.rgb_to_grayscale(img1)
  return img1, labels

# %%
### Decode and read images for all the image files in color
def read_images(image_paths, labels):
  img1 = tf.io.read_file(image_paths)
  img1 = tf.image.decode_image(img1, channels=3, dtype=tf.float32)
  return img1, labels

# %%
### Decode and read images for all the image files in color add saturation
def read_images_gamma(image_paths, labels):
  img1 = tf.io.read_file(image_paths)
  img1 = tf.image.decode_image(img1, channels=3, dtype=tf.float32)
  img1 = tf.image.adjust_gamma(img1, 1.5)
  img1 = tf.image.resize_with_crop_or_pad(img1, 400,640)
  return img1, labels

# %%
def create_equalized_image_set(ds, num_images = 5): 
    # create preview of images with labels
    images = []
    for i, t in enumerate(ds.take(num_images)): 
        images.append(
            {'label': t[1].numpy(), 
            'im' : histogram_equalization_grayscale(t[0].numpy())}
        )

    return images

# %%
def create_sharpened_image_set(ds, num_images = 5): 
    # create preview of images with labels
    images = []
    for i, t in enumerate(ds.take(num_images)): 
        images.append(
            {'label': t[1].numpy(), 
            'im' : sharpen_image(t[0].numpy())}
        )

    return images

# %%
def create_edges_image_set(ds, num_images = 5): 
    # create preview of images with labels
    images = []
    for i, t in enumerate(ds.take(num_images)): 
        images.append(
            {'label': t[1].numpy(), 
            'im' : edge_detection(t[0].numpy())}
        )

    return images

# %%
def create_image_set(ds, num_images = 5): 
    """ Create preview of images with labels 
    Takes the num_images from the dataset for viewing in plots
    
    Args: 
    ds (tensorflow dataset): tensorflow dataset with images
    """
    
    images = []
    for i, t in enumerate(ds.take(num_images)): 
        images.append(
            {'label': t[1].numpy(), 
            'im' : t[0].numpy()}
        )

    return images

# %%
full_training_dataset = full_training_dataset.sample(frac=1)
full_training_dataset.head()
print(len(full_training_dataset))
file_paths = full_training_dataset['full_path'].values
class_labels =  full_training_dataset['class'].values
tf_dataset = tf.data.Dataset.from_tensor_slices((file_paths, class_labels))
tf_dataset
# Out:
# 7909
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
dataset_size = tf_dataset.cardinality()
train_size = int(0.7 * len(full_training_dataset))
val_size = int(0.10 * len(full_training_dataset))
test_size = int(0.20 * len(full_training_dataset))

dataset_size
train_dataset = tf_dataset.take(train_size)
test_dataset = tf_dataset.skip(train_size)
val_dataset = test_dataset.take(val_size)
test_dataset = test_dataset.skip(val_size)

print(train_size)
print(train_dataset.cardinality().numpy())
print(val_dataset.cardinality().numpy())
print(test_dataset.cardinality().numpy())
# Out:
# 5536
# 5536
# 790
# 1583

# %%
tf_color_dataset = train_dataset.map(read_images_gamma)
train_gamma_color_dataset = create_image_set(tf_color_dataset, 300)
train_gamma_color_dataset[:2]
# Out:
# [{'label': 0,
#   'im': array([[[0.91878796, 0.81779987, 0.8068228 ],
#           [0.8846908 , 0.7850175 , 0.7850175 ],
#           [0.8903438 , 0.79045016, 0.79045016],
#           ...,
#           [0.8288263 , 0.742009  , 0.742009  ],
#           [0.8343579 , 0.7473408 , 0.7473408 ],
#           [0.81230515, 0.7366899 , 0.7313837 ]],
#
#          [[0.8903438 , 0.79045016, 0.7795974 ],
#           [0.90168566, 0.8013528 , 0.79045016],
#           [0.89600873, 0.81230515, 0.7958952 ],
#           ...,
#           [0.8343579 , 0.7473408 , 0.7473408 ],
#           [0.81230515, 0.7366899 , 0.7313837 ],
#           [0.7958952 , 0.7208095 , 0.7050449 ]],
#
#          [[0.8903438 , 0.79045016, 0.7795974 ],
#           [0.8903438 , 0.8068228 , 0.79045016],
#           [0.8790499 , 0.79045016, 0.79045016],
#           ...,
#           [0.81779987, 0.742009  , 0.7366899 ],
#           [0.81230515, 0.7366899 , 0.7313837 ],
#           [0.81230515, 0.7366899 , 0.7208095 ]],
#
#          ...,
#
#          [[0.25298223, 0.06924564, 0.46475804],
#           [0.2419037 , 0.05981177, 0.46020904],
#           [0.23461044, 0.05527037, 0.4511559 ],
#           ...,
#           [0.22739199, 0.06924564, 0.41994634],
#           [0.23099181, 0.07167517, 0.41554904],
#           [0.27181   , 0.10568224, 0.46020904]],
#
#          [[0.26422486, 0.07661724, 0.47849417],
#           [0.2419037 , 0.05981177, 0.46020904],
#           [0.23461044, 0.05527037, 0.4511559 ],
#           ...,
#           [0.24927102, 0.08423331, 0.43768913],
#           [0.24557815, 0.08682499, 0.43768913],
#           [0.26800847, 0.1001691 , 0.4511559 ]],
#
#          [[0.28719324, 0.09475531, 0.51105917],
#           [0.26800847, 0.07661724, 0.49236304],
#           [0.24927102, 0.06447117, 0.4693219 ],
#           ...,
#           [0.335002  , 0.14691877, 0.5395352 ],
#           [0.31079108, 0.13467965, 0.50636333],
#           [0.31079108, 0.13467965, 0.50636333]]], dtype=float32)},
#  {'label': 1,
#   'im': array([[[0.7366899 , 0.5636553 , 0.684207  ],
#           [0.7687947 , 0.59305984, 0.7208095 ],
#           [0.7741898 , 0.61794144, 0.742009  ],
#           ...,
#           [0.7687947 , 0.5299861 , 0.6998159 ],
#           [0.75268525, 0.52523285, 0.6893969 ],
#           [0.7687947 , 0.54914105, 0.6998159 ]],
#
#          [[0.7634123 , 0.59305984, 0.6998159 ],
#           [0.7741898 , 0.62295854, 0.7366899 ],
#           [0.8233069 , 0.67386645, 0.79045016],
#           ...,
#           [0.7795974 , 0.50168204, 0.6945999 ],
#           [0.7634123 , 0.4877254 , 0.6790302 ],
#           [0.8013528 , 0.5443311 , 0.7208095 ]],
#
#          [[0.8013528 , 0.6279892 , 0.7260902 ],
#           [0.8013528 , 0.64824593, 0.75268525],
#           [0.8343579 , 0.6893969 , 0.79045016],
#           ...,
#           [0.7634123 , 0.47390065, 0.67386645],
#           [0.7795974 , 0.49701527, 0.6893969 ],
#           [0.7795974 , 0.51576936, 0.6945999 ]],
#
#          ...,
#
#          [[0.75268525, 0.4693219 , 0.6687159 ],
#           [0.742009  , 0.4693219 , 0.66357857],
#           [0.7208095 , 0.4511559 , 0.6380907 ],
#           ...,
#           [0.8288263 , 0.81230515, 0.86219937],
#           [0.8013528 , 0.7958952 , 0.8399018 ],
#           [0.8233069 , 0.81230515, 0.87342095]],
#
#          [[0.742009  , 0.4693219 , 0.6584544 ],
#           [0.75804245, 0.48310244, 0.67386645],
#           [0.7958952 , 0.51576936, 0.71028686],
#           ...,
#           [0.8233069 , 0.7795974 , 0.8399018 ],
#           [0.8566067 , 0.8233069 , 0.8790499 ],
#           [0.81230515, 0.8068228 , 0.85102624]],
#
#          [[0.7634123 , 0.4877254 , 0.6790302 ],
#           [0.8013528 , 0.5204939 , 0.7155418 ],
#           [0.81779987, 0.5395352 , 0.7208095 ],
#           ...,
#           [0.8343579 , 0.7795974 , 0.8399018 ],
#           [0.81779987, 0.7795974 , 0.8233069 ],
#           [0.8068228 , 0.7741898 , 0.8288263 ]]], dtype=float32)}]

# %%
tf_valid_dataset = val_dataset.map(read_images_gamma)
valid_gamma_color_dataset = create_image_set(tf_valid_dataset, 50)
valid_gamma_color_dataset[:2]
# Out:
# [{'label': 0,
#   'im': array([[[0.8068228 , 0.7313837 , 0.8013528 ],
#           [0.7958952 , 0.7208095 , 0.79045016],
#           [0.7958952 , 0.7208095 , 0.79045016],
#           ...,
#           [0.8233069 , 0.7687947 , 0.8288263 ],
#           [0.8343579 , 0.7795974 , 0.8399018 ],
#           [0.8343579 , 0.7795974 , 0.8399018 ]],
#
#          [[0.8068228 , 0.7313837 , 0.8013528 ],
#           [0.7958952 , 0.7208095 , 0.79045016],
#           [0.7958952 , 0.7208095 , 0.79045016],
#           ...,
#           [0.8233069 , 0.7687947 , 0.8288263 ],
#           [0.8343579 , 0.7795974 , 0.8399018 ],
#           [0.8399018 , 0.7850175 , 0.8343579 ]],
#
#          [[0.7958952 , 0.7313837 , 0.7958952 ],
#           [0.79045016, 0.7155418 , 0.7850175 ],
#           [0.79045016, 0.7155418 , 0.7850175 ],
#           ...,
#           [0.8343579 , 0.7687947 , 0.8343579 ],
#           [0.8343579 , 0.7687947 , 0.8343579 ],
#           [0.8343579 , 0.7795974 , 0.8399018 ]],
#
#          ...,
#
#          [[0.7366899 , 0.6998159 , 0.7366899 ],
#           [0.75268525, 0.6998159 , 0.742009  ],
#           [0.7634123 , 0.7050449 , 0.7473408 ],
#           ...,
#           [0.5636553 , 0.39379537, 0.6380907 ],
#           [0.6129379 , 0.42878714, 0.6945999 ],
#           [0.6687159 , 0.45567498, 0.75804245]],
#
#          [[0.742009  , 0.71028686, 0.7313837 ],
#           [0.75268525, 0.6998159 , 0.742009  ],
#           [0.75804245, 0.7050449 , 0.7473408 ],
#           ...,
#           [0.6533435 , 0.46475804, 0.7473408 ],
#           [0.64316165, 0.45567498, 0.7366899 ],
#           [0.6533435 , 0.46020904, 0.75804245]],
#
#          [[0.7473408 , 0.7155418 , 0.7366899 ],
#           [0.7473408 , 0.6945999 , 0.7366899 ],
#           [0.742009  , 0.6893969 , 0.7313837 ],
#           ...,
#           [0.6945999 , 0.50168204, 0.79045016],
#           [0.67386645, 0.48310244, 0.7687947 ],
#           [0.64316165, 0.46020904, 0.742009  ]]], dtype=float32)},
#  {'label': 0,
#   'im': array([[[0.7260902 , 0.3473326 , 0.5782953 ],
#           [0.7366899 , 0.3473326 , 0.5685214 ],
#           [0.7313837 , 0.35563514, 0.5734014 ],
#           ...,
#           [0.5636553 , 0.29891452, 0.52523285],
#           [0.5636553 , 0.28719324, 0.51576936],
#           [0.5782953 , 0.3028562 , 0.52523285]],
#
#          [[0.742009  , 0.36821097, 0.5881245 ],
#           [0.75268525, 0.35981092, 0.583203  ],
#           [0.742009  , 0.36400285, 0.583203  ],
#           ...,
#           [0.5980089 , 0.31478405, 0.54914105],
#           [0.6129379 , 0.3268645 , 0.5636553 ],
#           [0.5980089 , 0.318794  , 0.5443311 ]],
#
#          [[0.7208095 , 0.35147572, 0.5685214 ],
#           [0.7473408 , 0.35563514, 0.5782953 ],
#           [0.7366899 , 0.35981092, 0.5782953 ],
#           ...,
#           [0.6129379 , 0.3268645 , 0.5734014 ],
#           [0.62295854, 0.335002  , 0.5734014 ],
#           [0.62295854, 0.33909568, 0.5685214 ]],
#
#          ...,
#
#          [[0.9882584 , 0.8288263 , 0.9130753 ],
#           [0.98240495, 0.8233069 , 0.9475287 ],
#           [0.9475287 , 0.7795974 , 0.9130753 ],
#           ...,
#           [0.9130753 , 0.67386645, 0.85102624],
#           [0.9591074 , 0.7155418 , 0.89600873],
#           [0.97073287, 0.7155418 , 0.9130753 ]],
#
#          [[0.9649143 , 0.81230515, 0.89600873],
#           [0.9649143 , 0.81230515, 0.91878796],
#           [0.9245125 , 0.7687947 , 0.8903438 ],
#           ...,
#           [0.9245125 , 0.7050449 , 0.8903438 ],
#           [0.9533122 , 0.7260902 , 0.90168566],
#           [0.97073287, 0.7260902 , 0.91878796]],
#
#          [[0.941757  , 0.8068228 , 0.8846908 ],
#           [0.9245125 , 0.7850175 , 0.8903438 ],
#           [0.935997  , 0.7795974 , 0.90168566],
#           ...,
#           [0.9765631 , 0.75804245, 0.93024886],
#           [1.        , 0.79045016, 0.9591074 ],
#           [1.        , 0.7634123 , 0.9475287 ]]], dtype=float32)}]

# %%
tf_test_dataset = test_dataset.map(read_images_gamma)
test_gamma_color_dataset = create_image_set(tf_test_dataset, 100)
test_gamma_color_dataset[:2]
# Out:
# [{'label': 0,
#   'im': array([[[0.75804245, 0.6893969 , 0.742009  ],
#           [0.7850175 , 0.6893969 , 0.75268525],
#           [0.7958952 , 0.6998159 , 0.7634123 ],
#           ...,
#           [0.7155418 , 0.6330332 , 0.6893969 ],
#           [0.7050449 , 0.62295854, 0.6790302 ],
#           [0.7155418 , 0.6330332 , 0.684207  ]],
#
#          [[0.7366899 , 0.6687159 , 0.7208095 ],
#           [0.7473408 , 0.66357857, 0.7208095 ],
#           [0.7634123 , 0.6790302 , 0.7366899 ],
#           ...,
#           [0.6945999 , 0.6129379 , 0.6790302 ],
#           [0.6790302 , 0.5980089 , 0.66357857],
#           [0.6893969 , 0.60794795, 0.66357857]],
#
#          [[0.7473408 , 0.66357857, 0.7208095 ],
#           [0.7473408 , 0.66357857, 0.7208095 ],
#           [0.7634123 , 0.6790302 , 0.7473408 ],
#           ...,
#           [0.6998159 , 0.60794795, 0.6790302 ],
#           [0.6945999 , 0.60297155, 0.67386645],
#           [0.6790302 , 0.5980089 , 0.6533435 ]],
#
#          ...,
#
#          [[0.67386645, 0.5539651 , 0.66357857],
#           [0.6279892 , 0.53475356, 0.6330332 ],
#           [0.7366899 , 0.6380907 , 0.742009  ],
#           ...,
#           [0.7208095 , 0.59305984, 0.742009  ],
#           [0.6945999 , 0.5685214 , 0.7155418 ],
#           [0.6893969 , 0.5636553 , 0.67386645]],
#
#          [[0.684207  , 0.5539651 , 0.6790302 ],
#           [0.6279892 , 0.51105917, 0.61794144],
#           [0.6945999 , 0.583203  , 0.6893969 ],
#           ...,
#           [0.6998159 , 0.5782953 , 0.71028686],
#           [0.6893969 , 0.5685214 , 0.6998159 ],
#           [0.6790302 , 0.5588032 , 0.6687159 ]],
#
#          [[0.6945999 , 0.5685214 , 0.6790302 ],
#           [0.6279892 , 0.51105917, 0.61794144],
#           [0.6687159 , 0.5588032 , 0.66357857],
#           ...,
#           [0.6998159 , 0.5782953 , 0.6998159 ],
#           [0.6790302 , 0.5588032 , 0.6790302 ],
#           [0.6533435 , 0.53475356, 0.64316165]]], dtype=float32)},
#  {'label': 0,
#   'im': array([[[0.41116717, 0.36400285, 0.43768913],
#           [0.43323052, 0.38093156, 0.42435908],
#           [0.42435908, 0.37667537, 0.40245003],
#           ...,
#           [0.86219937, 0.9591074 , 0.9130753 ],
#           [0.8678041 , 0.9533122 , 0.9130753 ],
#           [0.8678041 , 0.9591074 , 0.90168566]],
#
#          [[0.40245003, 0.3432059 , 0.44216293],
#           [0.43768913, 0.38520366, 0.43768913],
#           [0.44216293, 0.39379537, 0.41994634],
#           ...,
#           [0.8566067 , 0.9533122 , 0.9073745 ],
#           [0.8566067 , 0.9533122 , 0.9073745 ],
#           [0.86219937, 0.9533122 , 0.89600873]],
#
#          [[0.46475804, 0.41116717, 0.5204939 ],
#           [0.48310244, 0.43323052, 0.49701527],
#           [0.50636333, 0.45567498, 0.49236304],
#           ...,
#           [0.8454579 , 0.9591074 , 0.9073745 ],
#           [0.8454579 , 0.9591074 , 0.9073745 ],
#           [0.85102624, 0.9475287 , 0.8903438 ]],
#
#          ...,
#
#          [[0.46475804, 0.44216293, 0.54914105],
#           [0.5636553 , 0.54914105, 0.6330332 ],
#           [0.6279892 , 0.6129379 , 0.6687159 ],
#           ...,
#           [0.86219937, 0.8790499 , 0.91878796],
#           [0.8903438 , 0.8903438 , 0.9591074 ],
#           [0.93024886, 0.9073745 , 0.9882584 ]],
#
#          [[0.64316165, 0.5980089 , 0.7473408 ],
#           [0.66357857, 0.6380907 , 0.742009  ],
#           [0.7260902 , 0.6945999 , 0.7687947 ],
#           ...,
#           [0.8288263 , 0.8454579 , 0.87342095],
#           [0.85102624, 0.85102624, 0.89600873],
#           [0.8790499 , 0.8678041 , 0.93024886]],
#
#          [[0.684207  , 0.6279892 , 0.7850175 ],
#           [0.6998159 , 0.6533435 , 0.7634123 ],
#           [0.7208095 , 0.66357857, 0.75268525],
#           ...,
#           [0.8068228 , 0.81230515, 0.8399018 ],
#           [0.8068228 , 0.8068228 , 0.85102624],
#           [0.8399018 , 0.8288263 , 0.8903438 ]]], dtype=float32)}]

# %%
plt.imshow(train_gamma_color_dataset[4]['im'])

# %%
all_training_images_gamma_color = np.array([i['im'] for i in train_gamma_color_dataset])
all_training_labels_gamma_color = np.array([i['label'] for i in train_gamma_color_dataset])

all_valid_images_gamma_color = np.array([i['im'] for i in valid_gamma_color_dataset])
all_valid_labels_gamma_color = np.array([i['label'] for i in valid_gamma_color_dataset])

all_test_images_gamma_color = np.array([i['im'] for i in test_gamma_color_dataset])
all_test_labels_gamma_color = np.array([i['label'] for i in test_gamma_color_dataset])

print(all_training_images_gamma_color.shape)
print(all_training_labels_gamma_color.shape)

print(all_valid_images_gamma_color.shape)
# Out:
# (300, 400, 640, 3)
# (300,)
# (50, 400, 640, 3)

# %%
### Binary dataset set up
binary_train_data, binary_valid_data, binary_train_labels, binary_valid_labels = train_test_split_data(full_training_dataset.iloc[:5000], "full_path", "class")

print(binary_train_data[:5])
print(binary_train_labels[:5])
# Out:
# 6675    /content/drive/MyDrive/w281_final_project/Data...
# 1720    /content/drive/MyDrive/w281_final_project/Data...
# 1937    /content/drive/MyDrive/w281_final_project/Data...
# 2184    /content/drive/MyDrive/w281_final_project/Data...
# 3400    /content/drive/MyDrive/w281_final_project/Data...
# Name: full_path, dtype: object
# 6675    1
# 1720    0
# 1937    0
# 2184    1
# 3400    1
# Name: class, dtype: int64

# %%
binary_train_data.index = np.arange(len(binary_train_data))
binary_train_labels.index = np.arange(len(binary_train_labels))
binary_valid_data.index = np.arange(len(binary_valid_data))
binary_valid_labels.index = np.arange(len(binary_valid_data))

# %% [markdown]
# ### Creating Models

# %% [markdown]
# #### Binary Models

# %%
### Baseline TensorFlow model
def create_baseline_cnn(input_shape = (400,640,3), hidden_layers = 0, filters = 4, kernel_size = 3, learning_rate = 0.001, embedding_size = 0):
  
  input_layer = tf.keras.layers.Input(input_shape, batch_size=3, name="Input_Layer")
  convolve_layer = tf.keras.layers.Conv2D(filters=5, kernel_size=3, activation='relu')(input_layer)
  drop_layer = tf.keras.layers.Dropout(0.03)(convolve_layer)
  convolve_layer_2 = tf.keras.layers.Conv2D(filters= filters, kernel_size=3, activation='relu')(drop_layer)
  flatten = tf.keras.layers.Flatten()(convolve_layer_2)
  flatten = tf.keras.layers.Dense(128, activation="relu")(flatten)
  flatten = tf.keras.layers.Dense(64, activation="relu")(flatten)
  flatten = tf.keras.layers.Dense(32, activation="relu")(flatten)
  compress = tf.keras.layers.Dense(1, activation='sigmoid')(flatten)
  base_model = tf.keras.Model(inputs=[input_layer], outputs=[compress])
  base_model.compile(optimizer='sgd', loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

  return base_model

# %%
### Baseline Average CNN Model
def create_average_cnn(input_shape = (400, 640, 3), hidden_layers = 3, filters = 3, kernel_size = 3, learning_rate = 0.001, dropout_rate = 0.1):

  input_layer = tf.keras.layers.Input(shape=input_shape, batch_size = 3, name="Starting_Layer")

  # for i in range(hidden_layers):
  convolve1 = tf.keras.layers.Conv2D(filters=128, kernel_size=kernel_size, activation="ReLU", name = "Average_layer")(input_layer)
  avg_layer = tf.keras.layers.AveragePooling2D()(convolve1)
  convolve2 = tf.keras.layers.Conv2D(filters=64, kernel_size=kernel_size, activation="ReLU")(avg_layer)
  avg_layer = tf.keras.layers.AveragePooling2D()(convolve2)
  convolve3 = tf.keras.layers.Conv2D(filters=32, kernel_size=kernel_size, padding='valid', activation='relu')(avg_layer)
  avg_layer = tf.keras.layers.AveragePooling2D()(convolve3)
  avg_layer = tf.keras.layers.Dropout(dropout_rate)(avg_layer)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()(avg_layer)
  # flatten_layer = tf.keras.layers.Flatten()(global_average_layer)
  avg_layer = tf.keras.layers.Dropout(dropout_rate)(global_average_layer)
  # flatten = tf.keras.layers.Dense(128, activation="relu")(avg_layer)
  # flatten = tf.keras.layers.Dense(64, activation="relu")(flatten)
  # flatten = tf.keras.layers.Dense(32, activation="relu")(avg_layer)
  compress_layer = tf.keras.layers.Dense(8, activation = "ReLU")(avg_layer)
  classification_layer = tf.keras.layers.Dense(1, activation = "sigmoid")(compress_layer)
  model = tf.keras.Model(inputs=[input_layer], outputs=[classification_layer])

  model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate = learning_rate),
                                 loss = "binary_crossentropy",
                                 metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
  return model

# %%
def create_max_cnn_model(input_shape = (400, 640, 3), hidden_layers=3, filters=5, kernel_size=3, learning_rate=0.001, dropout_rate=0.1):

  input_layer = tf.keras.layers.Input(input_shape, batch_size=32, name="Starting_Layer", dtype=tf.float64)
  convolve_1 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='valid', activation='relu')(input_layer)
  max_1 = tf.keras.layers.MaxPool2D()(convolve_1)
  convolve_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='valid', activation='relu')(max_1)
  max_2 = tf.keras.layers.MaxPool2D()(convolve_2)
  convolve_3 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='valid', activation='relu')(max_2)
  max_3 = tf.keras.layers.MaxPool2D()(convolve_3)
  slight_adjustment = tf.keras.layers.Dropout(dropout_rate)(max_3)

  flatten = tf.keras.layers.GlobalMaxPooling2D()(slight_adjustment)
  flatten = tf.keras.layers.Dense(128, activation="relu")(flatten)
  flatten = tf.keras.layers.Dense(64, activation="relu")(flatten)
  flatten = tf.keras.layers.Dense(32, activation="relu")(flatten)
  compress = tf.keras.layers.Dense(1, activation='sigmoid')(flatten)
  model = tf.keras.Model(inputs=[input_layer], outputs=[compress])

  model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate),
                loss = "binary_crossentropy",
                metrics = ['Accuracy', tf.keras.metrics.Precision()])
  
  return model

# %%
def create_resnet_model(input_shape = (400, 640, 3), filters=3, kernel_size=3, learning_rate=0.001, dropout_rate=0.1):

  input_layer = tf.keras.layers.Input(input_shape, batch_size=32, name="Initial_input", dtype=tf.float64)

  weights = tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding="same", activation='relu')(input_layer)
  norm_1 = tf.keras.layers.BatchNormalization(axis=1, synchronized=True)(weights)

  added_layer = tf.keras.layers.Add()([input_layer, norm_1])

  weights_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding="same", activation='relu' )(added_layer)
  norm_2 = tf.keras.layers.BatchNormalization(axis=1, synchronized=True)(weights_2)

  added_layer_2 = tf.keras.layers.Add()([input_layer, norm_2])

  weights_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding="same", activation='relu')(added_layer_2)
  norm_3 = tf.keras.layers.BatchNormalization(axis=1, synchronized=True)(weights_3)

  added_layer_3 = tf.keras.layers.Add()([input_layer, norm_3])
  drop_layer = tf.keras.layers.Dropout(dropout_rate)(added_layer_3)

  flatten = tf.keras.layers.GlobalAveragePooling2D()(drop_layer)
  compress = tf.keras.layers.Dense(1, activation="sigmoid")(flatten)
  model = tf.keras.Model(inputs = [input_layer], outputs=[compress])

  model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate),
                loss = "binary_crossentropy",
                metrics = ["Accuray", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
  
  return model

# %%
# baseline_cnn_model = create_baseline_cnn()
average_cnn_model = create_average_cnn()
# max_cnn_model = create_max_cnn_model()
# resnet_cnn_model = create_resnet_model()

# %%
# baseline_cnn_model.summary()

# %%
average_cnn_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Starting_Layer (InputLayer)  [(3, 400, 640, 3)]       0
#
#  Average_layer (Conv2D)      (3, 398, 638, 128)        3584
#
#  average_pooling2d (AverageP  (3, 199, 319, 128)       0
#  ooling2D)
#
#  conv2d (Conv2D)             (3, 197, 317, 64)         73792
#
#  average_pooling2d_1 (Averag  (3, 98, 158, 64)         0
#  ePooling2D)
#
#  conv2d_1 (Conv2D)           (3, 96, 156, 32)          18464
#
#  average_pooling2d_2 (Averag  (3, 48, 78, 32)          0
#  ePooling2D)
#
#  dropout (Dropout)           (3, 48, 78, 32)           0
#
#  global_average_pooling2d (G  (3, 32)                  0
#  lobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (3, 32)                   0
#
#  dense (Dense)               (3, 8)                    264
#
#  dense_1 (Dense)             (3, 1)                    9
#
# =================================================================
# Total params: 96,113
# Trainable params: 96,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
# max_cnn_model.summary()

# %%
# resnet_cnn_model.summary()

# %%
# baseline_cnn_model_history = baseline_cnn_model.fit(all_training_images_gamma_color, all_training_labels_gamma_color, validation_data=([all_valid_images_gamma_color, all_valid_labels_gamma_color]), batch_size=32, epochs=4)

# %%
average_cnn_model_history = average_cnn_model.fit(all_training_images_gamma_color, all_training_labels_gamma_color, validation_data=([all_valid_images_gamma_color, all_valid_labels_gamma_color]), batch_size=32, epochs=4)
# Out:
# Epoch 1/4
